# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from plotly.tools import FigureFactory as FF

# %%
data_frame=pd.read_csv('/cleandata_frality.csv')

# %%
data
# Out:
#   Height  Weight  Age  Grip strength   Frailty
# 0   65.8     112   30             30          1
# 1   71.5     136   19             31          1
# 2   69.4     153   45             29          1
# 3   68.2     142   22             28          0
# 4   67.8     144   29             24          0
# 5   68.7     123   50             26          1
# 6   69.8     141   51             22          0
# 7   70.1     136   23             20          0
# 8   67.9     112   17             19          1
# 9   66.8     120   39             31          1

# %%
plt.scatter(data['Height '],data['Weight '], alpha=0.5)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Weight vs. Height')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
